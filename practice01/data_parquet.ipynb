# %%
from sqlalchemy import create_engine
source = create_engine('mysql+mysqlconnector://test:test123@db/test')

# %%
import pandas as pd

pd.read_sql('select current_date', con=source)
# Out:
#   current_date
# 0   2021-02-03

# %%
pip install pyarrow
# Out:
# ...
#      |████████████████████████████████| 20.7 MB 100 kB/s eta 0:00:01    |████▎                           | 2.8 MB 1.4 MB/s eta 0:00:13     |█████████▎                      | 6.0 MB 3.5 MB/s eta 0:00:05     |████████████▎                   | 7.9 MB 3.5 MB/s eta 0:00:04     |██████████████▊                 | 9.5 MB 3.5 MB/s eta 0:00:04
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install fastparquet
# Out:
# ...
#      |████████████████████████████████| 120 kB 1.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 3.2 MB 6.0 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 59 kB 675 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 25.3 MB 97 kB/s  eta 0:00:011   |▎                               | 256 kB 3.7 MB/s eta 0:00:07     |███████▌                        | 5.9 MB 4.2 MB/s eta 0:00:05     |███████▉                        | 6.1 MB 4.2 MB/s eta 0:00:05     |██████████▊                     | 8.5 MB 4.2 MB/s eta 0:00:05     |████████████████████████        | 19.0 MB 6.6 MB/s eta 0:00:01
# ...
#   ERROR: Command errored out with exit status 1:
# ...

# %%
import pandas as pd
df = pd.read_parquet('data.parquet', engine='auto', columns=None, use_nullable_dtypes=False)
df.head()
# Out:
#   vendor_id           pickup_at          dropoff_at  passenger_count  \
# 0         1 2019-06-01 00:55:13 2019-06-01 00:56:17                1
# 1         1 2019-06-01 00:06:31 2019-06-01 00:06:52                1
# 2         1 2019-06-01 00:17:05 2019-06-01 00:36:38                1
# 3         1 2019-06-01 00:59:02 2019-06-01 00:59:12                0
# 4         1 2019-06-01 00:03:25 2019-06-01 00:15:42                1
#
#    trip_distance rate_code_id store_and_fwd_flag  pickup_location_id  \
# 0            0.0            1                  N                 145
# 1            0.0            1                  N                 262
# 2            4.4            1                  N                  74
# 3            0.8            1                  N                 145
# 4            1.7            1                  N                 113
#
#    dropoff_location_id payment_type  fare_amount  extra  mta_tax  tip_amount  \
# ...

# %%
df.dtypes
# Out:
# vendor_id                        object
# pickup_at                datetime64[ns]
# dropoff_at               datetime64[ns]
# passenger_count                    int8
# trip_distance                   float32
# rate_code_id                     object
# store_and_fwd_flag               object
# pickup_location_id                int32
# dropoff_location_id               int32
# payment_type                     object
# fare_amount                     float32
# extra                           float32
# mta_tax                         float32
# tip_amount                      float32
# tolls_amount                    float32
# improvement_surcharge           float32
# total_amount                    float32
# congestion_surcharge            float32
# dtype: object

# %%
print(pd.io.sql.get_schema(df.reset_index(), 'test.trips', con=source))
# Out:
# CREATE TABLE `test.trips` (
# 	`index` BIGINT,
# 	vendor_id TEXT,
# 	pickup_at DATETIME,
# 	dropoff_at DATETIME,
# 	passenger_count BIGINT,
# 	trip_distance FLOAT(23),
# 	rate_code_id TEXT,
# 	store_and_fwd_flag TEXT,
# 	pickup_location_id INTEGER,
# 	dropoff_location_id INTEGER,
# 	payment_type TEXT,
# 	fare_amount FLOAT(23),
# 	extra FLOAT(23),
# 	mta_tax FLOAT(23),
# 	tip_amount FLOAT(23),
# 	tolls_amount FLOAT(23),
# 	improvement_surcharge FLOAT(23),
# 	total_amount FLOAT(23),
# 	congestion_surcharge FLOAT(23)
# )

# %%
query = pd.io.sql.get_schema(df.reset_index(), 'test.trips', con=source)
f = open("./queries/data_parquet.sql", "w+")
f.write(query)
f.close()
